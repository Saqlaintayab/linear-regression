# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %%
data= pd.read_csv('/Users/saqlaintayab/Downloads/The Data Science Course 2021 - All Resources/Part_5_Advanced_Statistical_Methods_(Machine_Learning)/S32_L186/1.01. Simple linear regression.csv')

# %%
data
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
data.describe()
# Out:
#                SAT        GPA
# count    84.000000  84.000000
# mean   1845.273810   3.330238
# std     104.530661   0.271617
# min    1634.000000   2.400000
# 25%    1772.000000   3.190000
# 50%    1846.000000   3.380000
# 75%    1934.000000   3.502500
# max    2050.000000   3.810000

# %%
y=data["GPA"]
x1=data["SAT"]
plt.scatter(x1,y)
plt.xlabel('SAT', fontsize=20)
plt.ylabel('GPA',fontsize=20)
plt.show()

# %%
x=sm.add_constant(x1)
results=sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.399
# Method:                 Least Squares   F-statistic:                     56.05
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):           7.20e-11
# Time:                        11:11:09   Log-Likelihood:                 12.672
# No. Observations:                  84   AIC:                            -21.34
# Df Residuals:                      82   BIC:                            -16.48
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2750      0.409      0.673      0.503      -0.538       1.088
# ...

# %%
plt.scatter(x1,y)
yhat=0.0017*x1+0.275
fig =plt.plot(x1,yhat,lw=4,c='orange',label='regression line')
plt.xlabel('SAT',fontsize=20)
plt.ylabel('GPA',fontsize=20)
plt.show()

# %%
dat=pd.read_csv('/Users/saqlaintayab/Downloads/real_estate_price_size.csv')
dat.describe()
# Out:
#                price         size
# count     100.000000   100.000000
# mean   292289.470160   853.024200
# std     77051.727525   297.941951
# min    154282.128000   479.750000
# 25%    234280.148000   643.330000
# 50%    280590.716000   696.405000
# 75%    335723.696000  1029.322500
# max    500681.128000  1842.510000

# %%
y=dat['size']
x1=dat['price']
dat_clean = dat[['price', 'size']].dropna()
x = dat_clean['price']
y = dat_clean['size']
plt.scatter(x, y)

# %%
x=sm.add_constant(x1)
resultss=sm.OLS(y,x).fit()
resultss.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   size   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.742
# Method:                 Least Squares   F-statistic:                     285.9
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):           8.13e-31
# Time:                        11:11:13   Log-Likelihood:                -642.81
# No. Observations:                 100   AIC:                             1290.
# Df Residuals:                      98   BIC:                             1295.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -122.3349     59.633     -2.051      0.043    -240.675      -3.994
# ...

# %%
plt.scatter(x1,y)
yhats=-122.3349+0.0033*x
fig =plt.plot(x1,yhats,lw=4,c='orange',label='regression line')
plt.xlabel('size',fontsize=20)
plt.ylabel('price',fontsize=20)
plt.show()
